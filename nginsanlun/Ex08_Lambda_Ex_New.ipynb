# %% [markdown]
# Q1). Write a lambda function that takes an integer 'year' and returns 'age'.

# %%
from datetime import datetime

current_year = datetime.now().year
age_calculate = lambda year : current_year-year
age_calculate(1997)
# Out:
# 28

# %% [markdown]
# Q2) Write a lambda function that takes a float "cost" and returns a float "price" by adding 10% to the cost.

# %%
cost_price = lambda cost : cost + cost * 10/100
cost_price(150)
# Out:
# 165.0

# %% [markdown]
# Q3) Write a lambda function that takes two strings 'name' , 'domain' and returns an email address (string).

# %%
gmail = lambda name, domain: name + '@' + domain + '.com'
gmail('minho','gmail')
# Out:
# 'minho@gmail.com'

# %% [markdown]
# Q4) Lambda in Data Science/Data Analysis

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Myanmar-Data-Tech/MMDT_T-PY101/refs/heads/master/data/rentals.csv")

# Q4.1) Create a new column called "size" where each entry is 
# determined by the number of bathrooms: 'large' if the number of bathrooms is greater than 3, and 'small' otherwise.

df['size'] = df['bathrooms'].apply(lambda x: 'large' if x > 3 else 'small')




# -----------------------------------------------------------------#
# Q4.2) Creat a new column called "price_category" where 
# Assign each entry as the following categories based on the price:
# If the price is greater than 100, the category should be 'premium'.
# Otherwise, the category should be 'standard'.

df['price_clean'] = (
    df['price']
    .astype(str)
    .str.replace(" ", "")
    .str.replace("$", "")
    .str.replace('"', '')
)

df['price_category'] = df['price_clean'].apply(
    lambda x: 'premium' if x > 100 else 'standard'
)
# -----------------------------------------------------------------#
# Do not change the code below: 
# Print the first five rows to see the data. You should have 11 columns

print(f"DataFrame has {df.shape[1]} columns")
df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7500\3195296709.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   .str.replace("$", "")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 27
#      13 # -----------------------------------------------------------------#
#      14 # Q4.2) Creat a new column called "price_category" where
#      15 # Assign each entry as the following categories based on the price:
#      16 # If the price is greater than 100, the category should be 'premium'.
#      17 # Otherwise, the category should be 'standard'.
#      19 df['price_clean'] = (
#      20     df['price']
#      21     .astype(str)
#    (...)
#      24     .str.replace('"', '')
#      25 )
# ---> 27 df['price_category'] = df['price_clean'].apply(
#      28     lambda x: 'premium' if x > 100 else 'standard'
#      29 )
#      30 # -----------------------------------------------------------------#
#      31 # Do not change the code below:
#      32 # Print the first five rows to see the data. You should have 11 columns
#      34 print(f"DataFrame has {df.shape[1]} columns")
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[20], line 28, in <lambda>(x)
#      13 # -----------------------------------------------------------------#
#      14 # Q4.2) Creat a new column called "price_category" where
#      15 # Assign each entry as the following categories based on the price:
#      16 # If the price is greater than 100, the category should be 'premium'.
#      17 # Otherwise, the category should be 'standard'.
#      19 df['price_clean'] = (
#      20     df['price']
#      21     .astype(str)
#    (...)
#      24     .str.replace('"', '')
#      25 )
#      27 df['price_category'] = df['price_clean'].apply(
# ---> 28     lambda x: 'premium' if x > 100 else 'standard'
#      29 )
#      30 # -----------------------------------------------------------------#
#      31 # Do not change the code below:
#      32 # Print the first five rows to see the data. You should have 11 columns
#      34 print(f"DataFrame has {df.shape[1]} columns")
#
# TypeError: '>' not supported between instances of 'str' and 'int'
